# %%
# %pip install psycopg2
# Out:
# ...
#      ---------------------------------------- 1.2/1.2 MB 8.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import psycopg2
import pandas as pd

# %%
DATABASE_URL="postgresql://technicaler_tafta_test:tafta_test_password@1.pgsqlserver.com:5432/technicaler_tafta_test?schema=public&connection_limit=60&pool_timeout=30"

# %%
df = pd.read_sql('technicaler_tafta_test.sql')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ad2432170bd4> in <module>
# ----> 1 df = pd.read_sql('technicaler_tafta_test.sql')
#
# TypeError: read_sql() missing 1 required positional argument: 'con'

# %%
query = 'SELECT * FROM public."User";'

# %%
user = pd.read_sql(query, conn)

# %%
user
# Out:
#                               id                            email  \
# 0      clb3yh3s5002666s0f8m7uup8   abubakarsaddiq.rabiu@gmail.com
# 1      clb3y4oxq000866s02pmx3x0e             superadmin@tafta.com
# 2      clb3ygu2f000h66s0hlpyjv21     odukoyaemmanuel608@gmail.com
# 3      clb3ygwhf000w66s0i41uyhhj             greatosewe@gmail.com
# 4      clb3yh2hl001y66s07ufdkaxb         asikablessing5@gmail.com
# ...                          ...                              ...
# 19497  cler35y290000l608ehabnsi5       lanrebuttercream@gmail.com
# 19498  clewuff2b0000jx08ctwbouba  ayodele@terraacademyforarts.com
# 19499  cler39hjw0000md08lum5dniv       asconwebservices@gmail.com
# 19500  clf09ktje000g1xucok6sqvo0                    test@test.com
# 19501  clf07tyyo0001mp08rr90x6nt          esiri.ekwale@aun.edu.ng
#
#       emailVerified image firstName     lastName               createdAt  \
# 0               NaT  None  Abubakar        Rabiu 2022-11-30 18:02:35.237
# ...

# %%
df = pd.read_sql(query, conn)

# %%
df
# Out:
#                               id                     userId taftaCenter  \
# 0      clb3ygu2f000i66s0b8hcphip  clb3ygu2f000h66s0hlpyjv21
# 1      clb3ygv9m000p66s06m62ysx1  clb3ygv9m000o66s0dy1o28xd
# 2      clb3ygwhf000x66s0ll8kuexf  clb3ygwhf000w66s0i41uyhhj
# 3      clb3ygxo2001466s0g2h1k2bl  clb3ygxo2001366s0df42frqs
# 4      clb3ygyvp001c66s0wz994fte  clb3ygyvp001b66s0925lwvik
# ...                          ...                        ...         ...
# 19493  cler35y290001l6086hh4s64r  cler35y290000l608ehabnsi5        None
# 19494  clf07usyp0006mp08g9iw28ge  clf07tyyo0001mp08rr90x6nt        None
# 19495  clewuff2b0001jx0849vyhfx4  clewuff2b0000jx08ctwbouba        None
# 19496  cler39hjw0001md0870p423ub  cler39hjw0000md08lum5dniv        None
# 19497  clf09ktjf000h1xuc4g5vpm6s  clf09ktje000g1xucok6sqvo0        None
#
#                                             homeAddress zipCode  phoneNumber  \
# 0                                          Kere eleyele          08115102306
# ...

# %%
cur = conn.cursor()

# Execute a SQL query to retrieve a list of all tables in the database
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' ORDER BY table_name")

# Fetch all the rows returned by the query
rows = cur.fetchall()

# Print the table names
print("Tables:")
for row in rows:
    print(row[0])

# Close the cursor and database connection
cur.close()
conn.close()
# Out:
# Tables:
# Account
# Cohort
# CohortCourse
# _CohortCourseToLocation
# _CohortToLocation
# Course
# Enrollment
# EnrollmentCompletionGraph
# geography_columns
# geometry_columns
# Location
# _prisma_migrations
# Profile
# raster_columns
# raster_overviews
# Referrer
# SeatBooking
# Session
# spatial_ref_sys
# User
# UserCohort
# VerificationToken

# %%
cur = conn.cursor()

# Execute the query to get all the schema names
cur.execute("SELECT * FROM information_schema.tables WHERE table_schema = 'public';")

# Fetch all the results and print them out
results = cur.fetchall()
for row in results:
    print(row)

# Close the cursor and database connection
cur.close()
# Out:
# ('technicaler_tafta_test', 'public', 'geography_columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None)
# ('technicaler_tafta_test', 'public', 'geometry_columns', 'VIEW', None, None, None, None, None, 'YES', 'NO', None)
# ('technicaler_tafta_test', 'public', 'spatial_ref_sys', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)
# ('technicaler_tafta_test', 'public', 'raster_columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None)
# ('technicaler_tafta_test', 'public', 'raster_overviews', 'VIEW', None, None, None, None, None, 'NO', 'NO', None)
# ('technicaler_tafta_test', 'public', 'Referrer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)
# ('technicaler_tafta_test', 'public', 'SeatBooking', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)
# ('technicaler_tafta_test', 'public', '_CohortToLocation', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)
# ...

# %%
# dest_tables.sort()
dest_tables
# Out:
# ['Account',
#  'Session',
#  'Enrollment',
#  'Profile',
#  'User',
#  '_prisma_migrations',
#  'VerificationToken',
#  'Cohort',
#  'Course',
#  'Location',
#  'Referrer',
#  '_CohortCourseToLocation',
#  'UserCohort',
#  '_CohortToLocation',
#  'SeatBooking',
#  'CohortCourse']

# %%
# tables_to_copy.sort()
tables_to_copy
# Out:
# ['spatial_ref_sys',
#  'Referrer',
#  'SeatBooking',
#  '_CohortToLocation',
#  'User',
#  '_prisma_migrations',
#  'Profile',
#  'VerificationToken',
#  'Account',
#  'Session',
#  'Enrollment',
#  'UserCohort',
#  '_CohortCourseToLocation',
#  'Cohort',
#  'Location',
#  'Course',
#  'CohortCourse']

# %%
source_conn = psycopg2.connect(
    host="1.pgsqlserver.com",
    port=5432,
    database="technicaler_tafta_test",
    user="technicaler_tafta_test",
    password="tafta_test_password"
)

# %%
dest_conn = psycopg2.connect(
    host="1.pgsqlserver.com",
    port=5432,
    database="technicaler_tafta",
    user="technicaler_tafta",
    password="Techpreneur365"
)

# %%
dest_conn = psycopg2.connect(
    host="192.168.0.36",
    database="tafta",
    user="postgres",
    password="Agent47a"
)

# %%
# Get the list of tables to copy from the source database
with source_conn.cursor() as source_cur:
    source_cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' AND table_type = 'BASE TABLE'")
    tables_to_copy = [row[0] for row in source_cur.fetchall()]

# %%
with dest_conn.cursor() as dest_cur:
    dest_cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' AND table_type = 'BASE TABLE'")
    dest_tables = [row[0] for row in dest_cur.fetchall()]

# %%
ordered_table_names = [
    # 'User',
    # 'Account',
    # 'Session',
    # 'VerificationToken',
    # 'Profile',
    # 'Referrer',
    # 'Cohort',
    # 'Location',
    # 'UserCohort',
    '_CohortToLocation',
    'Course',
    'CohortCourse',
    '_CohortCourseToLocation',
    'SeatBooking',
    'Enrollment',
]
len(ordered_table_names)
# Out:
# 6

# %%
dest_tables
# Out:
# ['Account',
#  'Session',
#  'Enrollment',
#  'Profile',
#  'User',
#  '_prisma_migrations',
#  'VerificationToken',
#  'Cohort',
#  'Course',
#  'Location',
#  'Referrer',
#  '_CohortCourseToLocation',
#  'UserCohort',
#  '_CohortToLocation',
#  'SeatBooking',
#  'CohortCourse']

# %%
ordered_table_names = []
while len(tables_to_copy) > 0:
    for table_name in tables_to_copy:
        if table_name == 'spatial_ref_sys':
            tables_to_copy.remove(table_name)
        else:
            with source_conn.cursor() as source_cur:
                source_cur.execute("SELECT conname, conrelid, confrelid FROM pg_constraint WHERE confrelid = (SELECT oid FROM pg_class WHERE relname = %s)", (table_name,))
                fk_constraints = source_cur.fetchall()
                # Check if all foreign key dependencies have already been added to the ordered list
                all_deps_added = all([fk_constraint[1] in [dest_conn.cursor().execute("SELECT oid FROM pg_class WHERE relname = %s", (name,)).fetchone()[0] for name in ordered_table_names] for fk_constraint in fk_constraints])
                if all_deps_added:
                    ordered_table_names.append(table_name)
                    tables_to_copy.remove(table_name)
                else:
                    break

# %%
# Iterate over the ordered list of tables and copy the data
for table_name in ordered_table_names:
    print(table_name)
    with source_conn.cursor() as source_cur, dest_conn.cursor() as dest_cur:
        # Get the column names of the table
        source_cur.execute("SELECT column_name FROM information_schema.columns WHERE table_name = %s", (table_name,))
        column_names = [f'"{row[0]}"' for row in source_cur.fetchall()]
        print(column_names)
        # Build the select statement
        select_statement = f'SELECT * FROM "{table_name}"'
        
        # Execute the select statement
        source_cur.execute(select_statement)
        rows = source_cur.fetchall()
        
        # Build the insert statement
#         insert_statement = f'INSERT INTO public."{table_name}" ({",".join(column_names)}) SELECT {",".join(column_names)} FROM "{table_name}"'
        
        # Execute the insert statement
        for row in rows:
            dest_cur.execute(f'INSERT INTO "{table_name}" ({",".join(column_names)}) VALUES ({",".join(["%s" for s in column_names])})', row)
        
    # Commit the changes
    dest_conn.commit()
# Out:
# _CohortToLocation
# ['"A"', '"B"']
# Course
# ['"uid"', '"id"', '"created_at"', '"active"', '"course_capacity"', '"course_colour"', '"description"', '"name"', '"slug"']
# CohortCourse
# ['"id"', '"cohortId"', '"courseId"', '"course_limit"', '"course_id"']
# _CohortCourseToLocation
# ['"A"', '"B"']
# SeatBooking
# ['"id"', '"userId"', '"seatNumber"', '"locationId"', '"Date"', '"timeslot"']
# Enrollment
# ['"uid"', '"id"', '"created_at"', '"expiry_date"', '"user_id"', '"course_name"', '"course_id"', '"completed_at"', '"expired"', '"is_free_trial"', '"completed"', '"started_at"', '"activated_at"', '"updated_at"', '"enrolled"', '"userCohortId"', '"percentage_completed"']

# %%
rows[0]
# Out:
# ('clb3yh3s5002666s0f8m7uup8',
#  'abubakarsaddiq.rabiu@gmail.com',
#  None,
#  None,
#  'Abubakar',
#  'Rabiu',
#  datetime.datetime(2022, 11, 30, 18, 2, 35, 237000),
#  'APPLICANT',
#  '$2a$12$0PzBW3kT.7v9LiAyBGcuNe.0fFSbA6bV7LFPP9TgHchvYUTonLseO',
#  '87905856')

# %%
# Iterate over the tables and copy the data
for table_name in dest_tables:
    with source_conn.cursor() as source_cur, dest_conn.cursor() as dest_cur:
        # Get the column names of the table
        source_cur.execute("SELECT column_name FROM information_schema.columns WHERE table_name = %s", (table_name,))
        column_names = [row[0] for row in source_cur.fetchall()]
        
        # Build the insert statement
        insert_statement = f"INSERT INTO {table_name} ({','.join(column_names)}) SELECT {','.join(column_names)} FROM {table_name}"
        
        # Execute the insert statement
        dest_cur.execute(insert_statement)
        
    # Commit the changes
    dest_conn.commit()

# %%
for row in source_cur:
    # Generate the SQL command to insert the data
    values = ",".join([f"'{value}'" for value in row])
    insert_sql = f'INSERT INTO public."User" * VALUES ({values});'
    dest_cur.execute(insert_sql)

# %%
# dest_conn.commit()

# %%
source_cur.close()
dest_cur.close()

# %%
source_conn.close()
dest_conn.close()
